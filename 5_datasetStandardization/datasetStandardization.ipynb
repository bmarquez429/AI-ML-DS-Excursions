# %% [markdown]
# ##### $\hspace{15pt}$ **Filename: datasetStandardization.ipynb**
# ##### $\hspace{1.5pt}$ **Date Created: October 30, 2023**
# ##### **Date Modified: November 16, 2023**
# ##### $\rule{10.5in}{1pt}$
# ##### **Standardize a dataset using basic Pandas operations or using the fit, transform, and fit_transform methods of sklearn.preprocessing.StandardScaler().**
# ##### $\rule{10.5in}{1pt}$

# %% [markdown]
# ##### Load modules and packages.

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
import numpy as np

# %% [markdown]
# ##### Create a dataset for demonstration.

# %%
np.random.seed(1)
dataset = pd.DataFrame(np.round(100*np.random.rand(10, 3), 2), columns = ["x1", "x2", "x3"])
dataset
# Out:
#       x1     x2     x3
# 0  41.70  72.03   0.01
# 1  30.23  14.68   9.23
# 2  18.63  34.56  39.68
# 3  53.88  41.92  68.52
# 4  20.45  87.81   2.74
# 5  67.05  41.73  55.87
# 6  14.04  19.81  80.07
# 7  96.83  31.34  69.23
# 8  87.64  89.46   8.50
# 9   3.91  16.98  87.81

# %% [markdown]
# $\hspace{1in}$

# %% [markdown]
# ##### **Standardize the dataset using basic Pandas operations.**

# %% [markdown]
# ##### Calculate the mean of each column.

# %%
columnMeans = dataset.mean(axis = 0)
columnMeans
# Out:
# x1    43.436
# x2    45.032
# x3    42.166
# dtype: float64

# %% [markdown]
# ##### Calculate the standard deviation of each column.

# %%
columnSds = dataset.std(axis = 0, ddof = 0)
columnSds
# Out:
# x1    30.363047
# x2    26.822986
# x3    32.696756
# dtype: float64

# %% [markdown]
# ##### Standardize each column.

# %%
standardizedDataset_v1 = (dataset - columnMeans)/columnSds
standardizedDataset_v1
# Out:
#          x1        x2        x3
# 0 -0.057175  1.006525 -1.289302
# 1 -0.434937 -1.131567 -1.007317
# 2 -0.816980 -0.390411 -0.076032
# 3  0.343971 -0.116020  0.806013
# 4 -0.757039  1.594826 -1.205808
# 5  0.777722 -0.123103  0.419124
# 6 -0.968151 -0.940313  1.159259
# 7  1.758519 -0.510458  0.827727
# 8  1.455849  1.656341 -1.029643
# 9 -1.301780 -1.045819  1.395979

# %% [markdown]
# $\hspace{1in}$

# %% [markdown]
# ##### **Standardize the dataset using the fit and transform methods of sklearn.preprocessing.StandardScaler().**

# %% [markdown]
# ##### Instantiate the StandardScaler class and fit the instance to the dataset.

# %%
scaler = StandardScaler()
scaler.fit(dataset)
# Out:
# StandardScaler()

# %% [markdown]
# ##### Display the calculated mean of each column.

# %%
scaler.mean_
# Out:
# array([43.436, 45.032, 42.166])

# %% [markdown]
# ##### Display the calculated standard deviation of each column.

# %%
scaler.scale_
# Out:
# array([30.36304734, 26.82298596, 32.69675617])

# %% [markdown]
# ##### Apply the transform method to standardize each column.

# %%
standardizedDataset_v2 = pd.DataFrame(scaler.transform(dataset), columns = ["x1", "x2", "x3"])
standardizedDataset_v2
# Out:
#          x1        x2        x3
# 0 -0.057175  1.006525 -1.289302
# 1 -0.434937 -1.131567 -1.007317
# 2 -0.816980 -0.390411 -0.076032
# 3  0.343971 -0.116020  0.806013
# 4 -0.757039  1.594826 -1.205808
# 5  0.777722 -0.123103  0.419124
# 6 -0.968151 -0.940313  1.159259
# 7  1.758519 -0.510458  0.827727
# 8  1.455849  1.656341 -1.029643
# 9 -1.301780 -1.045819  1.395979

# %% [markdown]
# $\hspace{1in}$

# %% [markdown]
# ##### **Standardize the dataset using the fit_transform method of sklearn.preprocessing.StandardScaler().**

# %% [markdown]
# ##### Instantiate the StandardScaler class and apply the fit_transform method to the dataset.

# %%
scaler = StandardScaler()
standardizedDataset_v3 = pd.DataFrame(scaler.fit_transform(dataset), columns = ["x1", "x2", "x3"])
standardizedDataset_v3
# Out:
#          x1        x2        x3
# 0 -0.057175  1.006525 -1.289302
# 1 -0.434937 -1.131567 -1.007317
# 2 -0.816980 -0.390411 -0.076032
# 3  0.343971 -0.116020  0.806013
# 4 -0.757039  1.594826 -1.205808
# 5  0.777722 -0.123103  0.419124
# 6 -0.968151 -0.940313  1.159259
# 7  1.758519 -0.510458  0.827727
# 8  1.455849  1.656341 -1.029643
# 9 -1.301780 -1.045819  1.395979
